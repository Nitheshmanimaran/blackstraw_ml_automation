# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append('../..')

# %%
DATA_PATH = '../../data/house-prices/'
TRAIN_DATASET_PATH = DATA_PATH + 'train.csv'
TEST_DATASET_PATH = DATA_PATH + 'test.csv'
TRAIN_DATASET_PATH
# Out:
# '../../data/house-prices/train.csv'

# %%
import pandas as pd

# %% [markdown]
# # Model training

# %%
from house_prices.train import build_model

build_model(TRAIN_DATASET_PATH)
# Out:
# /Users/tinyclues/opt/miniconda3/envs/dsp/lib/python3.10/site-packages/sklearn/utils/validation.py:758: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# /Users/tinyclues/opt/miniconda3/envs/dsp/lib/python3.10/site-packages/sklearn/utils/validation.py:758: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# {'rmsle': 0.22}

# %% [markdown]
# # Inference

# %%
from house_prices.inference import make_predictions

make_predictions(TEST_DATASET_PATH)
# Out:
# /Users/tinyclues/opt/miniconda3/envs/dsp/lib/python3.10/site-packages/sklearn/utils/validation.py:758: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# ...

# %%
import pandas as pd
import joblib
from house_prices import CONTINUOUS_FEATURE_COLUMNS, CATEGORICAL_FEATURE_COLUMNS, MODEL_PATH, LABEL_COLUMN
from house_prices.preprocess import preprocess
import warnings
warnings.filterwarnings('ignore')

# Sample user input
user_input = {
    'TotRmsAbvGrd': 7,
    'WoodDeckSF': 200,
    'YrSold': 2020,
    '1stFlrSF': 856,
    'Foundation': 'PConc',
    'KitchenQual': 'Gd'
}

# Create DataFrame
df = pd.DataFrame([user_input])

# Preprocess the DataFrame
df_preprocessed = preprocess(df, is_training=False)

# Load the model
model = joblib.load(MODEL_PATH)

# Make predictions
predictions = model.predict(df_preprocessed)

# Add predictions to the original DataFrame
df[LABEL_COLUMN] = predictions

# Display the predicted price
print(f"The predicted price for the house is: {predictions[0]}")
# Out:
# The predicted price for the house is: 211968.0
